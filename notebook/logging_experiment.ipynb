# %% [markdown]
# ## for logging

# %%
import logging
import os
from datetime import datetime

# %% [markdown]
# ### Create logs direcotry within notebook i.e notebook/logs

# %%
logs_dir=os.path.join(os.getcwd(),'logs')
logs_dir
# Out:
# 'c:\\Users\\s1296718\\OneDrive - Syngenta\\Desktop\\LLMOPs_course_KrishNaik\\document_portal\\notebook\\logs'

# %%
os.makedirs(logs_dir,exist_ok=True)

# %%
LOG_FILE= f"{datetime.now().strftime('%m-%m-%Y_%H-%M-%S')}.log"
LOG_FILE
# Out:
# '08-08-2025_14-39-11.log'

# %%
log_file_path=os.path.join(logs_dir,LOG_FILE)
log_file_path
# Out:
# 'c:\\Users\\s1296718\\OneDrive - Syngenta\\Desktop\\LLMOPs_course_KrishNaik\\document_portal\\notebook\\logs\\08-08-2025_14-39-11.log'

# %%
import logging
logging.basicConfig(
    filename=log_file_path,
    level=logging.INFO,
    format="[ %(asctime)s ] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s"
)

# %%
logger=logging.getLogger("DocumentPortal")
logger.info("DocumentPortal Logging has started")
